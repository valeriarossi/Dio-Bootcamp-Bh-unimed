# %%
animais = [1,2,3,4]
animais
# Out:
# [1, 2, 3, 4]

# %%
animais = ["cachorro", "gato" ,12345,6.5]
animais
# Out:
# ['cachorro', 'gato', 12345, 6.5]

# %%
animais[0]
# Out:
# 'cachorro'

# %%
animais[1]
# Out:
# 'gato'

# %%
animais[0] = "passaro"

# %%
animais[0]
# Out:
# 'passaro'

# %%
animais.remove ("gato")

# %%
animais
# Out:
# ['passaro', 12345, 6.5]

# %%
len(animais)
# Out:
# 3

# %%
"gato" in animais
# Out:
# False

# %%
"passaro" in animais
# Out:
# True

# %%
lista = [500,30,300,80,10]

# %%
max(lista)
# Out:
# 500

# %%
min(lista)
# Out:
# 10

# %%
animais.append(["leao"])

# %%
animais
# Out:
# ['passaro', 12345, 6.5, 'leao', 'cobra', 6, 'cobra', 6, ['leao']]

# %%
animais.extend(["cobra",6])

# %%
animais.count("cachorro")
# Out:
# 0

# %%
animais
# Out:
# ['passaro', 12345, 6.5, 'leao', 'cobra', 6, 'cobra', 6, ['leao'], 'cobra', 6]
