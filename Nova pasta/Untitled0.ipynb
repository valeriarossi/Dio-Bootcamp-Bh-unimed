# %%
print("ola mundo")
# Out:
# ola mundo

# %%
print("Aprendendo Python")
# Out:
# Aprendendo Python

# %%
"Dia de Python"
# Out:
# 'Dia de Python'

# %%
5 +10
# Out:
# 15

# %%
10/5
# Out:
# 2.0

# %%
7*9
# Out:
# 63

# %%
9-5
# Out:
# 4

# %%
#Comentario Python

# %%
preco =10
desconto = 5
preco - desconto
# Out:
# 5

# %%
frase ="ola hoje é segunda"
frase
# Out:
# 'ola hoje é segunda'

# %%
frase[0]
# Out:
# 'o'

# %%
frase[0:10]
# Out:
# 'ola hoje é'

# %%
frase.count("ola")
# Out:
# 1

# %%
frase.lower()
# Out:
# 'ola hoje é segunda'

# %%
frase.upper()
# Out:
# 'OLA HOJE É SEGUNDA'

# %%
frase.replace("ola","frases")
# Out:
# 'frases hoje é segunda'
